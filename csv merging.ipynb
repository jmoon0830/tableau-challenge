# %%
import pandas as pd

# %%
df_jan = pd.read_csv("data/JC-202001-citibike-tripdata.csv")
df_aug = pd.read_csv("data/JC-202008-citibike-tripdata.csv")

# %%
df_jan['month'] = "january"
df_jan.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1           377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2           288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3           435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4           231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# ...

# %%
df_aug['month'] = "august"
df_aug.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           561  2020-08-01 00:00:16.5960  2020-08-01 00:09:38.5610
# 1           236  2020-08-01 00:00:46.3900  2020-08-01 00:04:42.8890
# 2           384  2020-08-01 00:02:38.9250  2020-08-01 00:09:03.7590
# 3          1302  2020-08-01 00:03:27.0270  2020-08-01 00:25:09.2120
# 4          5561  2020-08-01 00:03:57.4810  2020-08-01 01:36:38.5000
#
#    start station id start station name  start station latitude  \
# 0              3185          City Hall               40.717733
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3185          City Hall               40.717733
# 4              3185          City Hall               40.717733
#
#    start station longitude  end station id end station name  \
# 0               -74.043845            3185        City Hall
# ...

# %%
merged_df = pd.concat([df_jan,df_aug])

# %%
merged_df.to_csv( "merged_csv.csv", index=False, encoding='utf-8-sig')
